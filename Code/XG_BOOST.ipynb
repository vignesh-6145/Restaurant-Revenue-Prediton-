# %% [markdown]
# importing required libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np 
import sklearn
from sklearn.model_selection import train_test_split

# %% [markdown]
# loading data

# %%
train_raw= pd.read_csv("train.csv")

# %%
train_raw.head()
# Out:
#    Id   Open Date        City  City Group Type  ...  P34  P35  P36  P37    revenue
# 0   0  07/17/1999    İstanbul  Big Cities   IL  ...    5    4    3    4  5653753.0
# 1   1  02/14/2008      Ankara  Big Cities   FC  ...    0    0    0    0  6923131.0
# 2   2  03/09/2013  Diyarbakır       Other   IL  ...    0    0    0    0  2055379.0
# 3   3  02/02/2012       Tokat       Other   IL  ...   18   12   12    6  2675511.0
# 4   4  05/09/2009   Gaziantep       Other   IL  ...    3    4    3    3  4316715.0
#
# [5 rows x 43 columns]

# %%
test_raw= pd.read_csv("test.csv")

# %%
test_raw.head()
# Out:
#    Id   Open Date            City  City Group Type  ...  P33  P34  P35  P36  P37
# 0   0  01/22/2011           Niğde       Other   FC  ...    0    0    0    0    0
# 1   1  03/18/2011           Konya       Other   IL  ...    0    0    0    0    0
# 2   2  10/30/2013          Ankara  Big Cities   FC  ...    0    0    0    0    0
# 3   3  05/06/2013         Kocaeli       Other   IL  ...    0    0    0    0    0
# 4   4  07/31/2013  Afyonkarahisar       Other   FC  ...    0    0    0    0    0
#
# [5 rows x 42 columns]

# %%
print('Test data Dimensions : ',test_raw.shape)
print('Train data Dimensions : ',train_raw.shape)
# Out:
# Test data Dimensions :  (100000, 42)
# Train data Dimensions :  (137, 43)

# %% [markdown]
# Outlier Detection and Elimination

# %%
print(train_raw['revenue'].describe())
sns.set(style='whitegrid', palette="deep", font_scale=1.1, rc={"figure.figsize": [8, 5]})
sns.distplot(train_raw['revenue'], norm_hist=False, kde=True).set(xlabel='revenue', ylabel='P(revenue)');
# Out:
# count    1.370000e+02
# mean     4.453533e+06
# std      2.576072e+06
# min      1.149870e+06
# 25%      2.999068e+06
# 50%      3.939804e+06
# 75%      5.166635e+06
# max      1.969694e+07
# Name: revenue, dtype: float64
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
train_pro1=train_raw[train_raw['revenue']< 10000000]

# %%
print(train_pro1['revenue'].describe())
sns.set(style='whitegrid', palette="deep", font_scale=1.1, rc={"figure.figsize": [8, 5]})
sns.distplot(train_pro1['revenue'], norm_hist=False, kde=True).set(xlabel='revenue', ylabel='P(revenue)');
# Out:
# count    1.340000e+02
# mean     4.181438e+06
# std      1.799596e+06
# min      1.149870e+06
# 25%      2.994569e+06
# 50%      3.887614e+06
# 75%      5.001114e+06
# max      9.652350e+06
# Name: revenue, dtype: float64
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# Data Transformation

# %%
import time
from datetime import datetime as dt

train_pro1['Open Date']= pd.to_datetime(train_pro1['Open Date'])
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """

# %%
train_pro1.head()
# Out:
#    Id  Open Date        City  City Group Type  ...  P34  P35  P36  P37    revenue
# 0   0 1999-07-17    İstanbul  Big Cities   IL  ...    5    4    3    4  5653753.0
# 1   1 2008-02-14      Ankara  Big Cities   FC  ...    0    0    0    0  6923131.0
# 2   2 2013-03-09  Diyarbakır       Other   IL  ...    0    0    0    0  2055379.0
# 3   3 2012-02-02       Tokat       Other   IL  ...   18   12   12    6  2675511.0
# 4   4 2009-05-09   Gaziantep       Other   IL  ...    3    4    3    3  4316715.0
#
# [5 rows x 43 columns]

# %%
train_pro1['year']=train_pro1['Open Date'].dt.year
train_pro1['month']= train_pro1['Open Date'].dt.month
train_pro1['day']= train_pro1['Open Date'].dt.day
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
train_pro1.head()
# Out:
#    Id  Open Date        City  City Group Type  ...  P37    revenue  year  month  day
# 0   0 1999-07-17    İstanbul  Big Cities   IL  ...    4  5653753.0  1999      7   17
# 1   1 2008-02-14      Ankara  Big Cities   FC  ...    0  6923131.0  2008      2   14
# 2   2 2013-03-09  Diyarbakır       Other   IL  ...    0  2055379.0  2013      3    9
# 3   3 2012-02-02       Tokat       Other   IL  ...    6  2675511.0  2012      2    2
# 4   4 2009-05-09   Gaziantep       Other   IL  ...    3  4316715.0  2009      5    9
#
# [5 rows x 46 columns]

# %%
train_year= train_pro1.drop(columns=['Open Date','Id', 'City', 'City Group', 'Type', 'month', 'day'])

# %%
train_year.head()
# Out:
#    P1   P2   P3   P4  P5  P6  P7  ...  P33  P34  P35  P36  P37    revenue  year
# 0   4  5.0  4.0  4.0   2   2   5  ...    5    5    4    3    4  5653753.0  1999
# 1   4  5.0  4.0  4.0   1   2   5  ...    0    0    0    0    0  6923131.0  2008
# 2   2  4.0  2.0  5.0   2   3   5  ...    0    0    0    0    0  2055379.0  2013
# 3   6  4.5  6.0  6.0   4   4  10  ...    6   18   12   12    6  2675511.0  2012
# 4   3  4.0  3.0  4.0   2   2   5  ...    2    3    4    3    3  4316715.0  2009
#
# [5 rows x 39 columns]

# %%
x= train_year.drop(columns= 'revenue')
y= train_year['revenue']

# %%
x.head()
# Out:
#    P1   P2   P3   P4  P5  P6  P7  P8  ...  P31  P32  P33  P34  P35  P36  P37  year
# 0   4  5.0  4.0  4.0   2   2   5   4  ...    3    4    5    5    4    3    4  1999
# 1   4  5.0  4.0  4.0   1   2   5   5  ...    0    0    0    0    0    0    0  2008
# 2   2  4.0  2.0  5.0   2   3   5   5  ...    0    0    0    0    0    0    0  2013
# 3   6  4.5  6.0  6.0   4   4  10   8  ...   12   10    6   18   12   12    6  2012
# 4   3  4.0  3.0  4.0   2   2   5   5  ...    1    3    2    3    4    3    3  2009
#
# [5 rows x 38 columns]

# %% [markdown]
# Splitting the training set into validation and training set

# %%
x_train, x_test, y_train, y_test= train_test_split(x, y, test_size=0.30, random_state=42)

# %% [markdown]
# Model Development

# %%
import xgboost as xgb
from xgboost import XGBRegressor
from sklearn.metrics import mean_squared_error

data_dmat= xgb.DMatrix(data= x, label= y)

# %%
xg_reg= XGBRegressor(objective ='reg:linear', colsample_bytree = 0.3, learning_rate = 0.1,
                max_depth = 5, alpha = 10, n_estimators = 10)

# %%
xg_reg.fit(x_train, y_train)
# Out:
# [17:56:21] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# XGBRegressor(alpha=10, colsample_bytree=0.3, max_depth=5, n_estimators=10)

# %%
pred=xg_reg.predict(x_test)
print(pred)
# Out:
# [2884808.  2965654.8 2941239.5 2716858.5 2540092.  3146034.5 1842492.
#  2826153.5 2723836.8 2684649.8 2838905.8 2829515.2 3189855.5 3034872.
#  1849705.1 2613636.  2746594.  2667213.2 2369917.2 2636083.5 2427979.5
#  3034872.  2421171.5 2954376.  2637780.8 2723836.8 2491389.2 2640120.2
#  1976278.2 2701063.2 2027398.9 3175402.  2637321.5 3002080.5 2623830.5
#  2435482.8 3054339.5 3175402.  2546901.5 2636083.5 2287629.8]

# %%
table= pd.DataFrame(data= pred, columns= ['Prediction'])
table['y-test']=y_test
table
# Out:
#      Prediction     y-test
# 0   2884808.000  5653753.0
# 1   2965654.750        NaN
# 2   2941239.500        NaN
# 3   2716858.500        NaN
# 4   2540092.000  4316715.0
# 5   3146034.500        NaN
# 6   1842492.000        NaN
# 7   2826153.500        NaN
# 8   2723836.750        NaN
# 9   2684649.750        NaN
# 10  2838905.750  3745135.0
# 11  2829515.250  5161370.0
# 12  3189855.500  1734634.0
# 13  3034872.000        NaN
# 14  1849705.125        NaN
# 15  2613636.000  3218918.0
# 16  2746594.000        NaN
# 17  2667213.250  8213524.0
# 18  2369917.250        NaN
# 19  2636083.500  2021934.0
# 20  2427979.500  5525735.0
# 21  3034872.000        NaN
# 22  2421171.500        NaN
# 23  2954376.000        NaN
# 24  2637780.750        NaN
# 25  2723836.750  3778621.0
# 26  2491389.250        NaN
# 27  2640120.250  5435276.0
# 28  1976278.250  4705945.0
# 29  2701063.250        NaN
# 30  2027398.875        NaN
# 31  3175402.000        NaN
# 32  2637321.500  3261924.0
# 33  3002080.500        NaN
# 34  2623830.500        NaN
# 35  2435482.750        NaN
# 36  3054339.500        NaN
# 37  3175402.000  2740687.0
# 38  2546901.500        NaN
# 39  2636083.500        NaN
# 40  2287629.750        NaN

# %%
y_test
# Out:
# 130    3376145.0
# 67     4052733.0
# 107    3248660.0
# 20     5525735.0
# 43     2732645.0
# 61     4350573.0
# 12     1734634.0
# 112    3784230.0
# 103    4429512.0
# 104    4467728.0
# 45     3752885.0
# 41     4554237.0
# 28     4705945.0
# 48     7201784.0
# 74     5500818.0
# 32     3261924.0
# 85     7495092.0
# 4      4316715.0
# 65     1756069.0
# 100    9652350.0
# 86     3351383.0
# 27     5435276.0
# 17     8213524.0
# 19     2021934.0
# 10     3745135.0
# 113    2097022.0
# 46     4250758.0
# 11     5161370.0
# 52     1763231.0
# 95     1270499.0
# 125    4780607.0
# 128    2383840.0
# 37     2740687.0
# 0      5653753.0
# 68     3836721.0
# 56     2390534.0
# 25     3778621.0
# 57     3258837.0
# 120    4067566.0
# 127    7592272.0
# 15     3218918.0
# Name: revenue, dtype: float64

# %%
rmse = np.sqrt(mean_squared_error(y_test, pred))
file1 = open("results.txt","a")
file1.write('XG Boost '+str(rmse))
file1.close()
print("RMSE: %f" % (rmse))
# Out:
# RMSE: 2364398.898457

# %%
from sklearn.metrics import mean_absolute_error,r2_score
r2= r2_score(y_test, pred)
r2
# Out:
# -0.653480723901656

# %%
from xgboost import cv

params = {"objective":"reg:linear",'colsample_bytree': 0.3,'learning_rate': 0.1,
                'max_depth': 5, 'alpha': 10}

cv_results = xgb.cv(dtrain=data_dmat, params=params, nfold=3,
                    num_boost_round=50, early_stopping_rounds=10,metrics="rmse", as_pandas=True, seed=123)
# Out:
# [18:09:11] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:09:11] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:09:11] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.

# %%
cv_results.head()
# Out:
#    train-rmse-mean  train-rmse-std  test-rmse-mean  test-rmse-std
# 0     4.170585e+06   104057.773151    4.167156e+06  226851.597182
# 1     3.834611e+06    97319.757322    3.852766e+06  222164.418523
# 2     3.532849e+06    95108.454265    3.556086e+06  231095.995161
# 3     3.261412e+06    81063.561320    3.292877e+06  239710.262499
# 4     3.016686e+06    86590.408596    3.075717e+06  242724.751689

# %%
xg_reg2= xgb.train(params=params, dtrain=data_dmat, num_boost_round=10)
# Out:
# [18:09:50] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.

# %%
xgb.plot_importance(xg_reg)
plt.rcParams['figure.figsize'] = [-10,-10]
plt.show()

# %%
test_raw.head()
# Out:
#    Id   Open Date            City  City Group Type  ...  P33  P34  P35  P36  P37
# 0   0  01/22/2011           Niğde       Other   FC  ...    0    0    0    0    0
# 1   1  03/18/2011           Konya       Other   IL  ...    0    0    0    0    0
# 2   2  10/30/2013          Ankara  Big Cities   FC  ...    0    0    0    0    0
# 3   3  05/06/2013         Kocaeli       Other   IL  ...    0    0    0    0    0
# 4   4  07/31/2013  Afyonkarahisar       Other   FC  ...    0    0    0    0    0
#
# [5 rows x 42 columns]

# %%
test_raw['Open Date']= pd.to_datetime(test_raw['Open Date'])

test_raw['year']= test_raw['Open Date'].dt.year
test_raw['month']= test_raw['Open Date'].dt.month
test_raw['day']= test_raw['Open Date'].dt.day

# %%
test= test_raw.drop(columns=['Open Date','Id', 'City', 'City Group', 'Type', 'month', 'day'])

# %%
test.head()
# Out:
#    P1   P2   P3   P4  P5  P6  P7  P8  ...  P31  P32  P33  P34  P35  P36  P37  year
# 0   1  4.0  4.0  4.0   1   2   5   4  ...    0    0    0    0    0    0    0  2011
# 1   3  4.0  4.0  4.0   2   2   5   3  ...    0    0    0    0    0    0    0  2011
# 2   3  4.0  4.0  4.0   2   2   5   4  ...    0    0    0    0    0    0    0  2013
# 3   2  4.0  4.0  4.0   2   3   5   4  ...    4    0    0    0    0    0    0  2013
# 4   2  4.0  4.0  4.0   1   2   5   4  ...    0    0    0    0    0    0    0  2013
#
# [5 rows x 38 columns]

# %%
test_pred=xg_reg.predict(test)
test_pred
# Out:
# array([2854916.2, 2147718.5, 2419325.2, ..., 2285343.2, 2637780.8,
#        2636083.5], dtype=float32)

# %%
xgb.plot_tree(xg_reg,num_trees=0)
plt.rcParams['figure.figsize'] = [50.0, 10.0]
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-41-b7602e70504b> in <module>()
# ----> 1 xgb.plot_tree(xg_reg,num_trees=1)
#       2 plt.rcParams['figure.figsize'] = [50.0, 10.0]
#       3 plt.show()
#
# /usr/local/lib/python3.7/dist-packages/xgboost/plotting.py in plot_tree(booster, fmap, num_trees, rankdir, ax, **kwargs)
#     273
#     274     if ax is None:
# --> 275         _, ax = plt.subplots(1, 1)
#     276
#     277     g = to_graphviz(booster, fmap=fmap, num_trees=num_trees,
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/pyplot.py in subplots(nrows, ncols, sharex, sharey, squeeze, subplot_kw, gridspec_kw, **fig_kw)
#    1175
#    1176     """
# -> 1177     fig = figure(**fig_kw)
#    1178     axs = fig.subplots(nrows=nrows, ncols=ncols, sharex=sharex, sharey=sharey,
#    1179                        squeeze=squeeze, subplot_kw=subplot_kw,
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/pyplot.py in figure(num, figsize, dpi, facecolor, edgecolor, frameon, FigureClass, clear, **kwargs)
#     544                                         frameon=frameon,
#     545                                         FigureClass=FigureClass,
# --> 546                                         **kwargs)
#     547
#     548         if figLabel:
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/backend_bases.py in new_figure_manager(cls, num, *args, **kwargs)
#    3355         from matplotlib.figure import Figure
#    3356         fig_cls = kwargs.pop('FigureClass', Figure)
# -> 3357         fig = fig_cls(*args, **kwargs)
#    3358         return cls.new_figure_manager_given_figure(num, fig)
#    3359
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/figure.py in __init__(self, figsize, dpi, facecolor, edgecolor, linewidth, frameon, subplotpars, tight_layout, constrained_layout)
#     347
#     348         if not np.isfinite(figsize).all() or (np.array(figsize) <= 0).any():
# --> 349             raise ValueError('figure size must be positive finite not '
#     350                              f'{figsize}')
#     351         self.bbox_inches = Bbox.from_bounds(0, 0, *figsize)
#
# ValueError: figure size must be positive finite not [-10.0, -10.0]
